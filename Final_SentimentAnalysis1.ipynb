# %% [markdown]
# #### Import Warnings

# %%
import warnings
warnings.filterwarnings(action="ignore")

# %% [markdown]
# #### Installation of libraries

# %%
# !pip install langdetect

# %%
# !pip install wordcloud

# %%
# Download the required NLTK resources
import nltk
nltk.download('stopwords')  # To get the stopwords corpus
nltk.download('punkt')      # To get the punkt tokenizer (for word_tokenize)
nltk.download("punkt_tab")
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')  # WordNet database
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ### Data Collection
# - Import Dataset

# %%
df= pd.read_csv("IMDB_movie_review_dataset.csv")

# %% [markdown]
# ### Data Inspection

# %%
df.head()
# Out:
#    review_rating   movie_id  \
# 0            5.0  tt9531772
# 1            5.0  tt9531772
# 2            6.0  tt9531772
# 3            3.0  tt9531772
# 4           10.0  tt9531772
#
#                                         review_title    movie_name  \
# 0  Not as good as Rohits previous movies, seems d...  Sooryavanshi
# 1                  Pathetic screenplay and dialogues  Sooryavanshi
# 2                        isse acha singham dekh leta  Sooryavanshi
# 3                Garbage that needs to be canned !!!  Sooryavanshi
# 4              Well made blockbuster by rohit Shetty  Sooryavanshi
#
#                                 review_detailed_main review_username  \
# 0  Story: During 93 Mumbai blasts 400kg RDX was u...       MuviFan73
# 1  The dialogues and screenplay are too cliche. C...       sndpkumar
# 2  Movie lose it's pace and cringe jokes are also...   imaryan-79408
# 3  I am amazed that in this day and age of the "e...           winak
# 4  A bit lengthy but well made movie epic blockbu...    vitthalmisal
#
#    movie_rating
# 0           5.9
# 1           5.9
# 2           5.9
# 3           5.9
# 4           5.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140596 entries, 0 to 140595
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   review_rating         130588 non-null  float64
#  1   movie_id              140596 non-null  object
#  2   review_title          140594 non-null  object
#  3   movie_name            140596 non-null  object
#  4   review_detailed_main  103832 non-null  object
#  5   review_username       140596 non-null  object
#  6   movie_rating          140596 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 7.5+ MB

# %%
df.shape
# Out:
# (140596, 7)

# %%
len(df)
# Out:
# 140596

# %% [markdown]
# ### Missing Values Handling

# %% [markdown]
# - Check for missing values

# %%
df.isnull().sum()
# Out:
# review_rating           10008
# movie_id                    0
# review_title                2
# movie_name                  0
# review_detailed_main    36764
# review_username             0
# movie_rating                0
# dtype: int64

# %%
df.dropna(subset=["review_rating"],inplace=True)

# %%
df.isna().sum()
# Out:
# review_rating               0
# movie_id                    0
# review_title                2
# movie_name                  0
# review_detailed_main    26756
# review_username             0
# movie_rating                0
# dtype: int64

# %%
df.dropna(subset=["review_title"],inplace=True)

# %%
df.isna().sum()
# Out:
# review_rating               0
# movie_id                    0
# review_title                0
# movie_name                  0
# review_detailed_main    26756
# review_username             0
# movie_rating                0
# dtype: int64

# %% [markdown]
# ### Data Type Verification

# %%
df.dtypes
# Out:
# review_rating           float64
# movie_id                 object
# review_title             object
# movie_name               object
# review_detailed_main     object
# review_username          object
# movie_rating            float64
# dtype: object

# %% [markdown]
# ### Duplicate Removal

# %% [markdown]
# - Identify duplicates

# %%
df[df.duplicated]
# Out:
#         review_rating   movie_id  \
# 7602              9.0  tt0108052
# 16046            10.0  tt1375666
# 16047             9.0  tt1375666
# 16048            10.0  tt1375666
# 16049            10.0  tt1375666
# ...               ...        ...
# 136966           10.0  tt0372873
# 136967            6.0  tt0372873
# 136968            8.0  tt0372873
# 136969            6.0  tt0372873
# 136970            8.0  tt0372873
#
#                                              review_title          movie_name  \
# 7602                                Great, touching movie    Schindler's List
# 16046           A one-of-a-kind mind-blowing masterpiece!           Inception
# 16047                      Matrix but in dreamworld? Nah.           Inception
# 16048   Is it possible the makers understand how incre...           Inception
# 16049   Inception was only less shocking to me than th...           Inception
# ...                                                   ...                 ...
# 136966  a movie to watch and enjoy if you like sci-fi/...  Dragon Wars: D-War
# 136967            The Special Effects where really great!  Dragon Wars: D-War
# 136968  The first time that i saw a east Asian dragon ...  Dragon Wars: D-War
# 136969  Not a really great movie, but way better than ...  Dragon Wars: D-War
# 136970                Battle of good and evil in our time  Dragon Wars: D-War
#
#                                      review_detailed_main  \
# 7602    Short & sweet: It's Realistic. It's Heart-wren...
# 16046                                                 NaN
# 16047                                                 NaN
# 16048   You only get to watch this for the first time ...
# 16049   When you wake up from a good dream, you feel t...
# ...                                                   ...
# 136966  I have watched this film a few times over the ...
# 136967  It wasn't return of the Jedi, but i think the ...
# 136968  Dragon wars told us a Korean legend about the ...
# 136969  People who rate this movie poorly are hard-hea...
# 136970  Young journalist, played by Jason Behr, must f...
#
#                  review_username  movie_rating
# 7602    skepticrunner-912-349677           9.0
# 16046           adrien_ngoc_1701           8.8
# 16047                clipturnity           8.8
# 16048        srcooper-756-646671           8.8
# 16049                    mrmocun           8.8
# ...                          ...           ...
# 136966            posserider1996           3.5
# 136967                robert_b_p           3.5
# 136968    thomaswayne-260-577445           3.5
# 136969               IrateTyrant           3.5
# 136970           davor-trcovic-1           3.5
#
# [16093 rows x 7 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [review_rating, movie_id, review_title, movie_name, review_detailed_main, review_username, movie_rating]
# Index: []

# %% [markdown]
# ### Summary Statistics

# %%
df.describe()
# Out:
#        review_rating   movie_rating
# count  114493.000000  114493.000000
# mean        5.632868       5.552816
# std         3.468224       2.159002
# min         1.000000       1.200000
# 25%         2.000000       3.600000
# 50%         6.000000       5.400000
# 75%         9.000000       8.100000
# max        10.000000       9.300000

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# - Create new feature 'Review' by Concatenating 'Review_Title' and 'Review_detailed_main' features

# %%
df['Review']= df["review_title"]+" : " + df["review_detailed_main"]

# %%
df.head()
# Out:
#    review_rating   movie_id  \
# 0            5.0  tt9531772
# 1            5.0  tt9531772
# 2            6.0  tt9531772
# 3            3.0  tt9531772
# 4           10.0  tt9531772
#
#                                         review_title    movie_name  \
# 0  Not as good as Rohits previous movies, seems d...  Sooryavanshi
# 1                  Pathetic screenplay and dialogues  Sooryavanshi
# 2                        isse acha singham dekh leta  Sooryavanshi
# 3                Garbage that needs to be canned !!!  Sooryavanshi
# 4              Well made blockbuster by rohit Shetty  Sooryavanshi
#
#                                 review_detailed_main review_username  \
# 0  Story: During 93 Mumbai blasts 400kg RDX was u...       MuviFan73
# 1  The dialogues and screenplay are too cliche. C...       sndpkumar
# 2  Movie lose it's pace and cringe jokes are also...   imaryan-79408
# 3  I am amazed that in this day and age of the "e...           winak
# 4  A bit lengthy but well made movie epic blockbu...    vitthalmisal
#
#    movie_rating                                             Review
# 0           5.9  Not as good as Rohits previous movies, seems d...
# 1           5.9  Pathetic screenplay and dialogues : The dialog...
# 2           5.9  isse acha singham dekh leta : Movie lose it's ...
# 3           5.9  Garbage that needs to be canned !!! : I am ama...
# 4           5.9  Well made blockbuster by rohit Shetty : A bit ...

# %%
df["Review"][0]
# Out:
# "Not as good as Rohits previous movies, seems desperate! : Story: During 93 Mumbai blasts 400kg RDX was used. The terrorists plan to detonate rest 600kgs in current future. Sooryavanshi and his team are in charge of neutralizing this havoc. Will they succeed? If yes than at what cost?\n\nCinematography & Direction: Average (Typical Rohit Shetty). A power pack entertainer which most of people would enjoy.\n\nActing (& music): I am not great fan when these things come. For example, we see Javed as comic artist so his portrayal failed. The comic nature of Vanshis to jumble up names is far away from fun. Vanshi aka Akahay looks old and comparison with other officers like Javed feels desperate. I liked Simmba's part although where he explains the consequences. Music was average.\n\nFinal Verdict: Singham and Simmba were better movies. I can't believe we waited so long for this movie. Disappointed."

# %%
df.isna().sum()
# Out:
# review_rating               0
# movie_id                    0
# review_title                0
# movie_name                  0
# review_detailed_main    23562
# review_username             0
# movie_rating                0
# Review                  23562
# dtype: int64

# %% [markdown]
# - Labelling Data Using Review Rating and add column 'Sentiment'

# %%
def label_sentiment(rating):
    if rating >=8:
        return "Positive"
    elif rating >= 5:
        return "Neutral"
    elif rating < 5:
        return "Negative"
    else:
        return np.nan

# %%
df["sentiment"]= df["review_rating"].apply(label_sentiment)

# %%
df.head()
# Out:
#    review_rating   movie_id  \
# 0            5.0  tt9531772
# 1            5.0  tt9531772
# 2            6.0  tt9531772
# 3            3.0  tt9531772
# 4           10.0  tt9531772
#
#                                         review_title    movie_name  \
# 0  Not as good as Rohits previous movies, seems d...  Sooryavanshi
# 1                  Pathetic screenplay and dialogues  Sooryavanshi
# 2                        isse acha singham dekh leta  Sooryavanshi
# 3                Garbage that needs to be canned !!!  Sooryavanshi
# 4              Well made blockbuster by rohit Shetty  Sooryavanshi
#
#                                 review_detailed_main review_username  \
# 0  Story: During 93 Mumbai blasts 400kg RDX was u...       MuviFan73
# 1  The dialogues and screenplay are too cliche. C...       sndpkumar
# 2  Movie lose it's pace and cringe jokes are also...   imaryan-79408
# 3  I am amazed that in this day and age of the "e...           winak
# 4  A bit lengthy but well made movie epic blockbu...    vitthalmisal
#
#    movie_rating                                             Review sentiment
# 0           5.9  Not as good as Rohits previous movies, seems d...   Neutral
# 1           5.9  Pathetic screenplay and dialogues : The dialog...   Neutral
# 2           5.9  isse acha singham dekh leta : Movie lose it's ...   Neutral
# 3           5.9  Garbage that needs to be canned !!! : I am ama...  Negative
# 4           5.9  Well made blockbuster by rohit Shetty : A bit ...  Positive

# %%
df.isna().sum()
# Out:
# review_rating               0
# movie_id                    0
# review_title                0
# movie_name                  0
# review_detailed_main    23562
# review_username             0
# movie_rating                0
# Review                  23562
# sentiment                   0
# dtype: int64

# %% [markdown]
# - Imputing 'NA' values

# %%
df['Review'] = df['Review'].fillna(df['review_title'])

# %%
df.isna().sum()
# Out:
# review_rating               0
# movie_id                    0
# review_title                0
# movie_name                  0
# review_detailed_main    23562
# review_username             0
# movie_rating                0
# Review                      0
# sentiment                   0
# dtype: int64

# %%
df['review_detailed_main'] = df['review_detailed_main'].fillna(df['review_title'])

# %%
df.isna().sum()
# Out:
# review_rating           0
# movie_id                0
# review_title            0
# movie_name              0
# review_detailed_main    0
# review_username         0
# movie_rating            0
# Review                  0
# sentiment               0
# dtype: int64

# %% [markdown]
# ### Saving File (.csv) with Labelled Data

# %%
df.to_csv("LabelledDatset.csv", index=False)

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Univariate/Bivariate Analysis

# %% [markdown]
# - Analyze Sentiment Distribution

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative    45679
# Positive    43100
# Neutral     25714
# Name: count, dtype: int64

# %%
sentiment_counts = df['sentiment'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(sentiment_counts,labels=sentiment_counts.index, autopct='%1.1f%%',colors = ['blue','yellow', 'green'])
plt.title("Sentiment Distribution")
plt.show()

# %% [markdown]
# - Analyze average review rating by movies

# %%
average_rating = df.groupby('movie_name')['review_rating'].mean().sort_values(ascending=False).head(10)
#print(average_rating)
plt.figure(figsize=(10, 6))
sns.barplot(x=average_rating.values, y=average_rating.index, palette='viridis')
plt.title('Average Rating by Movie')
plt.xlabel('Average Review Rating')
plt.ylabel('Movie Name')
plt.show()

# %% [markdown]
# - Analyze Review rating by sentiment

# %%
sns.boxplot(x='sentiment', y='review_rating', data=df, palette='coolwarm')
plt.title("Review Rating by Sentiment")
plt.xlabel('Sentiment')
plt.ylabel('Review Rating')
plt.show()

# %% [markdown]
# - Word Cloud

# %% [markdown]
# - Word Cloud for Positive Reviews

# %%
from wordcloud import WordCloud

# Generate a word cloud for positive reviews
positive_reviews = ' '.join(df[df['sentiment'] == 'Positive']['Review'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common Words in Positive Reviews")
plt.show()

# %% [markdown]
# - Word Cloud for Negative Review

# %%
from wordcloud import WordCloud

# Generate a word cloud for positive reviews
positive_reviews = ' '.join(df[df['sentiment'] == 'Negative']['Review'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common Words in Positive Reviews")
plt.show()

# %% [markdown]
# - Word Cloud for Neutral Reviews

# %%
from wordcloud import WordCloud

# Generate a word cloud for positive reviews
positive_reviews = ' '.join(df[df['sentiment'] == 'Neutral']['Review'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_reviews)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Common Words in Positive Reviews")
plt.show()

# %% [markdown]
# ### Feature Selection

# %%
df.columns
# Out:
# Index(['review_rating', 'movie_id', 'review_title', 'movie_name',
#        'review_detailed_main', 'review_username', 'movie_rating', 'Review',
#        'sentiment'],
#       dtype='object')

# %%
df= df[["Review","sentiment"]]

# %%
df.head()
# Out:
#                                               Review sentiment
# 0  Not as good as Rohits previous movies, seems d...   Neutral
# 1  Pathetic screenplay and dialogues : The dialog...   Neutral
# 2  isse acha singham dekh leta : Movie lose it's ...   Neutral
# 3  Garbage that needs to be canned !!! : I am ama...  Negative
# 4  Well made blockbuster by rohit Shetty : A bit ...  Positive

# %%
df.isna().sum()

# %% [markdown]
# ### Checking data imbalance for dependent column

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# Negative    45679
# Positive    43100
# Neutral     25714
# Name: count, dtype: int64

# %% [markdown]
# ### Label Encoding on dependent column

# %% [markdown]
# - import libraries

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder =LabelEncoder()
df["sentiment"]= encoder.fit_transform(df["sentiment"])

# %%
df.head()
# Out:
#                                               Review  sentiment
# 0  Not as good as Rohits previous movies, seems d...          1
# 1  Pathetic screenplay and dialogues : The dialog...          1
# 2  isse acha singham dekh leta : Movie lose it's ...          1
# 3  Garbage that needs to be canned !!! : I am ama...          0
# 4  Well made blockbuster by rohit Shetty : A bit ...          2

# %%
encoder.classes_
# Out:
# array(['Negative', 'Neutral', 'Positive'], dtype=object)

# %% [markdown]
# - Save encoder

# %%
import pickle

# %%
with open("label_encoder.pkl", "wb") as encoder_file:
    pickle.dump(encoder, encoder_file)

# %% [markdown]
# ### TEXT PRE-PROCESSING (NLP PIPELINE)

# %% [markdown]
# - Sentence Tokenization, Work Tokenization, POS Tagging, Removing Stop Words, Lemmatization

# %% [markdown]
# #### import libraries

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
## for removing special symbols used RE (Regular Expression)
import re

# %% [markdown]
# #### Build Vocabulary

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\all\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stopwords_to_remove=stopwords.words('english')
# stopwords_to_remove=set(stopwords_to_remove)

#lemmatization object creation
lemmatizer = WordNetLemmatizer()

# empty vocabulary to store all  the values
vocabulary=[]

cnt=1
for review in df["Review"]:

    #Sentence Tokenization
    sentences= nltk.sent_tokenize(review)


    for sentence in sentences:
        # print("\n===================\n")
        # print(sentence)
        sentence = sentence.lower()
        sentence = re.sub(r'[^a-zA-Z\s]', '', sentence)
        # print("\n---------------\n")

        # word tokenization
        words= nltk.word_tokenize(sentence)

        #removing stop words and lemmatiation
        words=[ lemmatizer.lemmatize(word.strip()) for word in words if word.strip() not in stopwords_to_remove]

        # Adding word to vocabulary where all words will be kept
        vocabulary.extend([ word for word in words])

    # print(cnt)
    cnt+=1

# %%
vocabulary = list(set(vocabulary))
len(vocabulary)

# %% [markdown]
# ### Text Representation

# %% [markdown]
#  - Convert text into numerical form

# %% [markdown]
# #### Import Library

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #### Vectorization

# %% [markdown]
# - Convert text into numerical form

# %% [markdown]
# - Get all reviews

# %%
reviews = [review.lower() for review in df['review']]

# %%
#create a vectorizer
vectorizer = TfidfVectorizer(vocabulary=vocabulary )

#convert the input reviews to numeric format using vocabulary
vectorizer.fit(reviews)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 2
#       1 #create a vectorizer
# ----> 2 vectorizer = TfidfVectorizer(vocabulary=vocabulary )
#       4 #convert the input reviews to numeric format using vocabulary
#       5 vectorizer.fit(reviews)
#
# NameError: name 'vocabulary' is not defined

# %%
vectorizer.get_feature_names_out()

# %% [markdown]
# #### Save Vectorizer

# %%
with open("tfidf_vectorizer.pkl", "wb") as vectorizer_file:
    pickle.dump(vectorizer, vectorizer_file)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Split data into x and y

# %% [markdown]
# - Split data w.r.t independent variables(x) and dependent variable(y)

# %%
x = vectorizer.transform(reviews)
y = df['sentiment']

# %%
print(type(x_sparsed))

# %%
x[0]

# %% [markdown]
# ### Split dataset into training and testing sets

# %% [markdown]
# #### import library

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Spliting dataset into x_train, x_test, y_train, y_test => (70/30)

# %%
x_train,x_test,y_train,y_test= train_test_split(x_sparsed,y, test_size=0.3, random_state=123456789)

# %% [markdown]
# ### --MODEL SELECTION

# %% [markdown]
# ### Using Logistic Regression

# %% [markdown]
# #### Import libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %% [markdown]
# #### Train Model

# %%
# Initialize a Logistic Regression model
# model = LogisticRegression(max_iter=1000)

#with Best HyperParameters after grid_search_cv
model = LogisticRegression(max_iter=1000, solver='newton-cg')

# Train model
model.fit(x_train, y_train)

# %% [markdown]
# #### Save Model

# %%
with open("model_logistic.pkl", "wb") as model_file:
    pickle.dump(model, model_file)

# %% [markdown]
# #### Model Evaluation

# %%
y_pred = model.predict(x_test)
y_true = y_test

# %%
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred,average='macro')
recall = recall_score(y_true, y_pred,average='weighted')
f1 = f1_score(y_true, y_pred,average='micro')

print(f"accuray = {accuracy}")
print(f"precision = {precision}")
print(f"recall = {recall}")
print(f"f1 = {f1}")

# %% [markdown]
# - Classification Report

# %%
report = classification_report(y_test, y_pred)
print(report)

# %% [markdown]
# - Training and Testing Accuracy

# %%
print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))

# %% [markdown]
# ### Using XGBoost

# %% [markdown]
# #### Import Libraries

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %% [markdown]
# #### Train Model

# %%
model_xgb = XGBClassifier()

# Train model
model_xgb.fit(x_train, y_train)

# %% [markdown]
# #### Save Model

# %%
# import pickle
with open('model_xgb.pkl', 'wb') as file:
    pickle.dump(model_xgb, file)

# %% [markdown]
# #### Model Evaluation

# %%
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred,average='macro')
recall = recall_score(y_true, y_pred,average='weighted')
f1 = f1_score(y_true, y_pred,average='micro')

print(f"accuray = {accuracy}")
print(f"precision = {precision}")
print(f"recall = {recall}")
print(f"f1 = {f1}")

# %% [markdown]
# - Classification Report

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 report = classification_report(y_test, y_pred)
#       2 print(report)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# - Training and Testing Accuracy

# %%
print("Training Accuracy :", model_xgb.score(x_train, y_train))
print("Testing Accuracy :", model_xgb.score(x_test, y_test))

# %% [markdown]
# ## Optimization

# %% [markdown]
# #### Import Libraries

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Hyperparameter selection

# %%
# create a dictionary with all possible hyperparamters along with their possible values
hyper_prameters = {
    "penalty": ["l1", "l2", "elasticnet"],
    "C": [10, 5, 1.0, 0.1, 0.01],
    "solver": ['lbfgs', 'liblinear', 'newton-cg', 'saga']
}

# %%
# create a grid search object
grid_search_cv = GridSearchCV(estimator=model, param_grid=hyper_prameters,  n_jobs=-1, cv=3)

# %%
grid_search_cv

# %%
grid_search_cv.fit(x_train,y_train)

# %%
# GridSearchCV(cv=3, estimator=LogisticRegression(max_iter=1000), n_jobs=-1,
#              param_grid={'C': [10, 5, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg', 'saga']})

# best_estimator_: LogisticRegression
# LogisticRegression(max_iter=1000, solver='newton-cg')

#  LogisticRegression
# LogisticRegression(max_iter=1000, solver='newton-cg')
